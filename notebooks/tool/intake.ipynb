# %%
import intake
from ecgtools import Builder
from ecgtools.parsers import parse_cmip6

# %%
yaml_data = """

"""

# %%
S3_ROOT = "s3://s3.ap-southeast-1.wasabisys.com/aria"
S3_OPTIONS = {
    # "url": "https://s3.ap-southeast-1.wasabisys.com",
    "key": "2OZXTO5SZNG63705TCSF",
    "secret": "Wse1ERWDbi9l5LE3wrWD3rRuBo66sytpFo7BeTqe"
}

# %%
import os
import intake

os.environ["S3_ACCESS_KEY"] = S3_OPTIONS["key"]
os.environ["S3_SECRET_KEY"] = S3_OPTIONS["secret"]

cat = intake.open_catalog("catalog.yaml")
sources = cat.wasabi_csv_source

df = sources.read()
df.head()
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\Users\zharif\miniconda3\envs\lavenv\lib\site-packages\s3fs\core.py:114, in _error_wrapper(func, args, kwargs, retries)
#     113 try:
# --> 114     return await func(*args, **kwargs)
#     115 except S3_RETRYABLE_ERRORS as e:
#
# File c:\Users\zharif\miniconda3\envs\lavenv\lib\site-packages\aiobotocore\context.py:36, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      35     await resolve_awaitable(hook())
# ---> 36 return await func(*args, **kwargs)
#
# File c:\Users\zharif\miniconda3\envs\lavenv\lib\site-packages\aiobotocore\client.py:424, in AioBaseClient._make_api_call(self, operation_name, api_params)
#     423     error_class = self.exceptions.from_code(error_code)
# --> 424     raise error_class(parsed_response, operation_name)
#     425 else:
#
# ...
