# %%
# %pip install -q intake_esgf
# %pip install -q globus_sdk.tokenstorage
# %pip install -q ipywidgets
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pangeo-downloader (from versions: none)
# ERROR: No matching distribution found for pangeo-downloader

# %%
import intake_esgf
cat = intake_esgf.ESGFCatalog()

# %%
cat.variable_info("latest = true AND (experiment_id = G6sulfur) AND (realm = atmos) AND (frequency = day) AND (institution_id = NCAR) AND (variable_id = tas OR tasmax OR pr)")
# Out:
#             variable_units                       variable_long_name  \
# variable_id
# hus                      1                        Specific Humidity
# pr              kg m-2 s-1                            Precipitation
# psl                     Pa                       Sea Level Pressure
# rsds                 W m-2  Surface Downwelling Shortwave Radiation
# sfcWind              m s-1                  Near-Surface Wind Speed
# ta                       K                          Air Temperature
# tas                      K             Near-Surface Air Temperature
# ua                   m s-1                            Eastward Wind
# va                   m s-1                           Northward Wind
# zg                       m                      Geopotential Height
#
#                                       cf_standard_name
# variable_id
# hus                                  specific_humidity
# pr                                  precipitation_flux
# ...

# %%
cat.search(variable_id="tas", table_id="day")
# Out:
#    Searching indices:   0%|          |0/1 [       ?index/s]
# C:\Users\zharif\miniconda3\Lib\site-packages\intake_esgf\core\globus.py:97: UserWarning: We are processing your request but the search has returned 65,406 records and it may take some time to complete. Your search will execute faster if you can add more search criteria.
#   warnings.warn(
# Summary information for 30037 results:
# mip_era                                                     [CMIP6]
# activity_drs      [AerChemMIP, C4MIP, CDRMIP, CFMIP, CMIP, DAMIP...
# institution_id    [AS-RCEC, BCC, CNRM-CERFACS, EC-Earth-Consorti...
# source_id         [TaiESM1, BCC-ESM1, CNRM-ESM2-1, EC-Earth3-Aer...
# experiment_id     [histSST, hist-piAer, hist-piNTCF, ssp370-lowN...
# member_id         [r1i1p1f1, r2i1p1f1, r3i1p1f1, r1i1p1f2, r2i1p...
# table_id                                                      [day]
# variable_id                                                   [tas]
# ...

# %%
from intake_esgf import supported_projects
print(supported_projects())
# Out:
# ['cmip6', 'cmip5', 'cmip3', 'obs4mips', 'drcdp', 'input4mips']

# %%
cat.search(
    experiment_id="G6sulfur",
    realm="atmos",
    frequency="day",
    institution_id="NCAR",
    variable_id=["tas", "tasmax", "pr"],   # OR operation
    latest=True
)
# Out:
#    Searching indices:   0%|          |0/1 [       ?index/s]
# Summary information for 5 results:
# mip_era                        [CMIP6]
# activity_drs                  [GeoMIP]
# institution_id                  [NCAR]
# source_id                [CESM2-WACCM]
# experiment_id               [G6sulfur]
# member_id         [r1i1p1f2, r2i1p1f2]
# table_id                         [day]
# variable_id          [pr, tas, tasmax]
# grid_label                        [gn]
# dtype: object

# %%
dsets = cat.to_dataset_dict()
# Out:
# Get file information:   0%|          |0/1 [       ?index/s]
# ...
# pr_day_CESM2-WACCM_G6sulfur_r1i1p1f2_...:   0%|          |0.00/663M [?B/s]
# pr_day_CESM2-WACCM_G6sulfur_r1i1p1f2_...:   0%|          |0.00/663M [?B/s]
# pr_day_CESM2-WACCM_G6sulfur_r1i1p1f2_...:   0%|          |0.00/662M [?B/s]
# pr_day_CESM2-WACCM_G6sulfur_r1i1p1f2_...:   0%|          |0.00/663M [?B/s]
# pr_day_CESM2-WACCM_G6sulfur_r1i1p1f2_...:   0%|          |0.00/663M [?B/s]
# pr_day_CESM2-WACCM_G6sulfur_r1i1p1f2_...:   0%|          |0.00/663M [?B/s]
# pr_day_CESM2-WACCM_G6sulfur_r1i1p1f2_...:   0%|          |0.00/663M [?B/s]
# pr_day_CESM2-WACCM_G6sulfur_r1i1p1f2_...:   0%|          |0.00/663M [?B/s]
# pr_day_CESM2-WACCM_G6sulfur_r1i1p1f2_...:   0%|          |0.00/66.4M [?B/s]
# tas_day_CESM2-WACCM_G6sulfur_r1i1p1f2...:   0%|          |0.00/458M [?B/s]
# tas_day_CESM2-WACCM_G6sulfur_r1i1p1f2...:   0%|          |0.00/458M [?B/s]
# tas_day_CESM2-WACCM_G6sulfur_r1i1p1f2...:   0%|          |0.00/458M [?B/s]
# ...
